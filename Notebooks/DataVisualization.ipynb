# %% [markdown]
# ## Data

# %%
import matplotlib.pyplot as plt
import numpy as np

test_weeks = list(range(78, 92))  # weeks 78-91
ann_gini_test = [0.537544262695423,
 0.5223692033293699,
 0.5171713461747744,
 0.4541003294545338,
 0.45109954509047157,
 0.5102937637606357,
 0.5130482007520409,
 0.566969406213647,
 0.5526593069335102,
 0.44832437221846066,
 0.4579863498285288,
 0.5068955584466115,
 0.43365533359587527,
 0.5151795485942912]
ann_auc_test = [(g + 1) / 2 for g in ann_gini_test]
lr_gini_test = [0.4751979667424917,
 0.5134247069814846,
 0.47809473283273474,
 0.4389364947985137,
 0.42145156651544236,
 0.44103713441155645,
 0.42318175619069853,
 0.49188138457487507,
 0.5132164106263644,
 0.4479398668998744,
 0.4948790921136694,
 0.4890417853383522,
 0.44227546852196475,
 0.4544680822433931]
lr_auc_test = [(g + 1) / 2 for g in lr_gini_test]
rf_gini_test= [0.509593303274648,
 0.4958400571881545,
 0.47561078463380113,
 0.42602853108719985,
 0.409972136404823,
 0.5020867678802965,
 0.4548741403160128,
 0.48312120369743883,
 0.5221644378113992,
 0.49004415145943225,
 0.5131094863694137,
 0.4968520197257362,
 0.4753025026447264,
 0.4885104934782998]
rf_auc_test = [(g + 1) / 2 for g in rf_gini_test]
lgbm_gini_test = [0.6098777603415293,
 0.6085124002038389,
 0.5515004353030797,
 0.4728987130175111,
 0.4628913196087343,
 0.5653569594247558,
 0.53679934537378,
 0.5661197599713701,
 0.5735162473684869,
 0.5468254247173729,
 0.5879839050620173,
 0.5883797562114081,
 0.5401465603113442,
 0.5877469185639701]
lgbm_auc_test = [(g + 1) / 2 for g in lgbm_gini_test]

sve_gini_test = [0.6126544954618018,
 0.6067358869826169,
 0.5559214822069867,
 0.49801515815440545,
 0.47891056744629057,
 0.5813381533720519,
 0.5441833732733259,
 0.5749451571590796,
 0.578733069020013,
 0.5507613672739058,
 0.5998157645568287,
 0.5982577206903765,
 0.5481535820277008,
 0.6022051666756374]
sve_auc_test = [(g + 1) / 2 for g in sve_gini_test]
crm_gini_test = [0.6098777603415293,
 0.6095705226204629,
 0.5559595712264664,
 0.4960919876008245,
 0.4873036637071262,
 0.580607245861483,
 0.5452895162390168,
 0.5865711872710804,
 0.5936654156421413,
 0.5516943250235056,
 0.5920789565034166,
 0.5927930402328365,
 0.5429717200888524,
 0.6166104315804581]
crm_auc_test = [(g + 1) / 2 for g in crm_gini_test]

# %%
ann_min_slopes = [-0.015175059366053185,
 -0.010186458260324183,
 -0.02555296568772622,
 -0.024115830908473936,
 -0.011803785317453455,
 -0.005846816644711336,
 0.0,
 0.0,
 -0.0006419403412522955,
 -0.0027256199756554834,
 -0.001941787895744327,
 -0.0038185411536548856,
Create the plot
plt.figure(figsize=(12, 6))
plt.plot(test_weeks, ann_gini_test, color='orange', label='ANN', marker='*')
plt.plot(test_weeks, lr_gini_test, color='purple', label='LR', marker='v')
plt.plot(test_weeks, rf_gini_test, color='pink', label='RF', marker='+')
plt.plot(test_weeks, lgbm_gini_test, color='blue', label='LGBM', marker='o')
plt.plot(test_weeks, sve_gini_test, color='red', label='SVE', marker='s')
#plt.plot(test_weeks, crm_gini_test, color='green', label='CRM', marker='^')

# Add labels and title
plt.xlabel('Week')
plt.ylabel('Gini')
plt.title('Weekly Gini Scores on the Test Set')
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(test_weeks, ann_auc_test, color='orange', label='ANN', marker='*')
plt.plot(test_weeks, lr_auc_test, color='purple', label='LR', marker='v')
plt.plot(test_weeks, rf_auc_test, color='pink', label='RF', marker='+')
plt.plot(test_weeks, lgbm_auc_test, color='blue', label='LGBM', marker='o')
plt.plot(test_weeks, sve_auc_test, color='red', label='SVE', marker='s')
#plt.plot(test_weeks, crm_auc_test, color='green', label='CRM', marker='^')

# Add labels and title
plt.xlabel('Week')
plt.ylabel('AUC')
plt.title('Weekly AUC Scores on the Test Set')
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(test_weeks_stability, ann_min_slopes, color='orange', label='ANN', marker='*')
plt.plot(test_weeks_stability, lr_min_slopes, color='purple', label='LR', marker='v')
plt.plot(test_weeks_stability, rf_min_slopes, color='pink', label='RF', marker='+')
plt.plot(test_weeks_stability, lgbm_min_slopes, color='blue', label='LGBM', marker='o')
plt.plot(test_weeks_stability, sve_min_slopes, color='red', label='SVE', marker='s')
#plt.plot(test_weeks_stability, crm_min_slopes, color='green', label='CRM', marker='^')

# Add labels and title
plt.xlabel('Week')
plt.ylabel('min(0, a)')
plt.title('Weekly min(0, a) on the Test Set')
plt.legend()
plt.grid(True, alpha=0.3)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create the plot
plt.figure(figsize=(12, 6))
plt.plot(test_weeks, [r**2 for r in ann_residuals_test], color='orange', label='ANN', marker='*')
plt.plot(test_weeks, [r**2 for r in lr_residuals_test], color='purple', label='LR', marker='v')
plt.plot(test_weeks, [r**2 for r in rf_residuals_test], color='pink', label='RF', marker='+')
plt.plot(test_weeks, [r**2 for r in lgbm_residuals_test], color='blue', label='LGBM', marker='o')
plt.plot(test_weeks, [r**2 for r in sve_residuals_test], color='red', label='SVE', marker='s')
#plt.plot(test_weeks, [r**2 for r in crm_residuals_test], color='green', label='CRM', marker='^')

# Add labels and title
plt.xlabel('Week')
plt.ylabel('Squared Residuals')
plt.title('Weekly Squared Residuals on the Test Set')
plt.legend()
plt.grid(True, alpha=0.3)
#plt.axhline(y=0, color='black', linestyle='--', alpha=0.7, label='Zero line')
# Show the plot
plt.tight_layout()
plt.show()
